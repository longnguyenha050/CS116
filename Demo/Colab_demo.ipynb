# %%
# !pip install streamlit-option-menu
# !pip install streamlit

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹
# changed 22 packages in 2s
# ⠹
# ⠹3 packages are looking for funding
# ⠹  run `npm fund` for details
# ⠹

# %%
# !curl ifconfig.me
# Out:
# 35.237.102.58

# %%
# !streamlit run /content/ML/app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.237.102.58:8501
#
# ⠴⠦your url is: https://ten-friends-drop.loca.lt
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [21:30:26] WARNING: /workspace/src/collective/../data/../common/error_msg.h:80: If you are loading a serialized model (like pickle in Python, RDS in R) or
# configuration generated by an older version of XGBoost, please export the model by calling
# `Booster.save_model` from that version first, then load it back in current version. See:
#
#     https://xgboost.readthedocs.io/en/stable/tutorials/saving_model.html
#
# for more details about differences between saving model and serializing.
#
#   warnings.warn(smsg, UserWarning)
# ...
